# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB, GaussianNB

from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB


dataframe=pd.read_excel(r'C:\Users\acer\Desktop\Python\Ticket1.xls')
dataframe2=pd.read_excel(r'C:\Users\acer\Desktop\Python\TicketSamples.xls')
#print(dataframe)

x=dataframe["Subject"]
z=dataframe["TicketDescription"]
y=dataframe["Classifications"]



x1=dataframe2["Subject"]
z1=dataframe2["TicketDescription"]

x_train, z_train, y_train,= x[0:], z[0:], y[0:]
x_test,z_test=x1[0:], z1[0:]

l1=list(x_train)
l2=list(z_train)
l3=list(y_train)

l4=list(x_test)
l5=list(z_test)

res1 = [str(i) +(" , ")+ str(j) for i, j in zip(l1, l2)] 
res2 = [str(i) +(" , ")+ str(j) for i, j in zip(l4, l5)] 

count_vect=CountVectorizer()
X_train_tf=count_vect.fit_transform(res1)
tfidf_transformer = TfidfTransformer()
X_train_tfidf=tfidf_transformer.fit_transform(X_train_tf)
X_train_tfidf.shape

clf=MultinomialNB().fit(X_train_tfidf, l3)

X_test_tf=count_vect.transform(res2)
X_test_tfidf=tfidf_transformer.transform(X_test_tf)
predicted=clf.predict(X_test_tfidf)

#text_clf = Pipeline([('vect', TfidfVectorizer()), 
 #                     ('clf', MultinomialNB()) ])
#text_clf.fit(res1,l3)

#predicted=text_clf.predict(res2)
a1=list(predicted)


print("CLASSIFIED DATA IS")



for x in range(len(a1)):
    print("\n\n",x+1,". Subject  :  ",l4[x])
    print("\n     Ticket Description  :  ",l5[x])
    print("\n     Predicted Classification  :  ",a1[x])


print("\n\n")
    
from sklearn import metrics
from sklearn.metrics import accuracy_score
import numpy as np

print("\n\n")
#print('Accuracy achieved is ' + str(np.mean(predicted==y_test)))
#print(metrics.classification_report(y_test, predicted, target_names=news_test.target_names)),
#metrics.confusion_matrix(y_test, predicted)
# Out:
# CLASSIFIED DATA IS
#
#
#  1 . Subject  :   RPP/Covid Sample - No Order for Adams Mary Executive Medical .
#
#      Ticket Description  :   Orders not visible on VO.
#
#      Predicted Classification  :   Incident
#
#
#  2 . Subject  :   Sanford guide
#
#      Ticket Description  :   Results failure
#
#      Predicted Classification  :   Incident
#
#
#  3 . Subject  :   Default Test Request - Connecticut Foot Care Centers, LLC
#
#      Ticket Description  :   Default test request
#
#      Predicted Classification  :   Service Request
#
#
#  4 . Subject  :   case
#
#      Ticket Description  :   delete case
#
#      Predicted Classification  :   Service Request
#
#
#  5 . Subject  :   new feature
#
#      Ticket Description  :   Feature request
#
#      Predicted Classification  :   Service Request
#
#
#  6 . Subject  :   New feature 87661
#
#      Ticket Description  :   New Requirement
#
#      Predicted Classification  :   Service Request
#
#
#  7 . Subject  :   Ageing report
#
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB, GaussianNB


from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB


dataframe=pd.read_excel(r'C:\Users\acer\Desktop\Python\Ticket1.xls')
dataframe2=pd.read_excel(r'C:\Users\acer\Desktop\Python\TicketSamples.xls')
#print(dataframe)

x=dataframe["Subject"]
z=dataframe["TicketDescription"]
y=dataframe["Classifications"]



#x1=dataframe2["Subject"]
#z1=dataframe2["LISCustomer"]

x_train, z_train, y_train = x[0:100], z[0:100], y[0:100]
x_test, z_test, y_test = x[100:], z[100:], y[100:]

l1=list(x_train)
l2=list(z_train)
l3=list(y_train)

l4=list(x_test)
l5=list(z_test)

res1 = [str(i) +(" , ")+ str(j) for i, j in zip(l1, l2)] 
res2 = [str(i) +(" , ")+ str(j) for i, j in zip(l4, l5)] 

count_vect=CountVectorizer()
X_train_tf=count_vect.fit_transform(res1)
tfidf_transformer = TfidfTransformer()
X_train_tfidf=tfidf_transformer.fit_transform(X_train_tf)
X_train_tfidf.shape

clf=MultinomialNB().fit(X_train_tfidf, l3)

X_test_tf=count_vect.transform(res2)
X_test_tfidf=tfidf_transformer.transform(X_test_tf)
predicted=clf.predict(X_test_tfidf)

#text_clf = Pipeline([('vect', TfidfVectorizer()), 
   #                   ('clf', MultinomialNB()) ])
#text_clf.fit(res1,l3)

#predicted=text_clf.predict(res2)
a1=list(predicted)


print("CLASSIFIED DATA IS")



for x in range(len(a1)):
    print("\n\n",x+1,". Subject  :  ",l4[x])
    print("\n     Ticket Description  :  ",l5[x])
    print("\n     Predicted Classification  :  ",a1[x])


    
from sklearn import metrics
from sklearn.metrics import accuracy_score
import numpy as np

print("\n\n")
print('Accuracy achieved is ' + str(np.mean(predicted==y_test)))
print(metrics.classification_report(y_test, predicted)),
metrics.confusion_matrix(y_test, predicted)
# Out:
# CLASSIFIED DATA IS
#
#
#  1 . Subject  :   JA_KEYSTONE UROLOGY SPECIALIST_Theranoxtix Inc_NEW PROVIDER STARTED
#
#      Ticket Description  :   update ip address
#
#      Predicted Classification  :   Service Request
#
#
#  2 . Subject  :   Order Crossover from VO to DX Random Fails
#
#      Ticket Description  :   Random failures in orders crossing over from VO to Dx.
#
#      Predicted Classification  :   Service Request
#
#
#  3 . Subject  :   Error while attempting to order in a new acct
#
#      Ticket Description  :   Unable to place an order for one of the accounts as the user is getting an error stating "Unable to Proceed"
#
#      Predicted Classification  :   Incident
#
#
#  4 . Subject  :   Case and Claim monitoring (PLUS,LIS) -19 May 2020
#
#      Ticket Description  :   Unable to place an order for one of the accounts as the user is getting an error stating "Unable to Proceed"
#
#      Predicted Classification  :   Incident
#
#
# ...

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB, GaussianNB


from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer

dataframe=pd.read_excel(r'C:\Users\acer\Desktop\Python\Ticket1.xls')
dataframe2=pd.read_excel(r'C:\Users\acer\Desktop\Python\TicketSamples.xls')
#print(dataframe)

x=dataframe["Subject"]
#z=dataframe["TicketDescription"]
y=dataframe["Classifications"]



#x1=dataframe2["Subject"]
#z1=dataframe2["LISCustomer"]

x_train, y_train = x[0:100], y[0:100]
x_test, y_test = x[100:], y[100:]

l1=list(x_train)
l2=list(y_train)

l4=list(x_test)
l5=list(z_test)


count_vect=CountVectorizer()
X_train_tf=count_vect.fit_transform(l1)
tfidf_transformer = TfidfTransformer()
X_train_tfidf=tfidf_transformer.fit_transform(X_train_tf)
X_train_tfidf.shape

clf=MultinomialNB().fit(X_train_tfidf, l3)

X_test_tf=count_vect.transform(l4)
X_test_tfidf=tfidf_transformer.transform(X_test_tf)
predicted=clf.predict(X_test_tfidf)
#text_clf = Pipeline([('vect', TfidfVectorizer()), 
 #                     ('clf', MultinomialNB()) ])
#text_clf.fit(l1,l2)

#predicted=text_clf.predict(l4)
a1=list(predicted)


print("CLASSIFIED DATA IS")



for x in range(len(a1)):
    print("\n\n",x+1,". Subject  :  ",l4[x])
   # print("\n     Ticket Description  :  ",l5[x])
    print("\n     Predicted Classification  :  ",a1[x])


    
from sklearn import metrics
from sklearn.metrics import accuracy_score
import numpy as np

print("\n\n")
print('Accuracy achieved is ' + str(np.mean(predicted==y_test)))
#print(metrics.classification_report(y_test, predicted, target_names=news_test.target_names)),
metrics.confusion_matrix(y_test, predicted)
# Out:
# CLASSIFIED DATA IS
#
#
#  1 . Subject  :   JA_KEYSTONE UROLOGY SPECIALIST_Theranoxtix Inc_NEW PROVIDER STARTED
#
#      Predicted Classification  :   Incident
#
#
#  2 . Subject  :   Order Crossover from VO to DX Random Fails
#
#      Predicted Classification  :   Service Request
#
#
#  3 . Subject  :   Error while attempting to order in a new acct
#
#      Predicted Classification  :   Service Request
#
#
#  4 . Subject  :   Case and Claim monitoring (PLUS,LIS) -19 May 2020
#
#      Predicted Classification  :   Service Request
#
#
#  5 . Subject  :   Vital Axis support tickets
#
#      Predicted Classification  :   Service Request
#
#
#  6 . Subject  :   Route3-Capstone UTI - LIS Results Failure
#
#      Predicted Classification  :   Incident
#
#
#  7 . Subject  :   Cleargate Laboratory - Houston_l2l_order_Captiva Lab, LLC Failure
#
#      Predicted Classification  :   Incident
#
#
#  8 . Subject  :   FWC.Athena-FWC.VA-Orders.Inbound Failure
#
# ...
