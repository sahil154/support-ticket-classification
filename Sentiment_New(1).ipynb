# %%
#Sentiment Analysis With ALL STOPWORDS
import string
import nltk
import pandas as pd

from collections import Counter

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize
import xlrd 
def listToString(s):   
    str1 = ""  
    for ele in s:  
        str1 += ele 
        str1+=" "
    return str1

def sentiment_scores(sentence):
    obj = SentimentIntensityAnalyzer()
    scores = obj.polarity_scores(sentence)
    print("POST PROCESSING:\n",sentence)
    print()
    print("Overall sentiment dictionary is: ", scores)
    print("Complaint was rated as ", scores['neg']*100, "% Negative") 
    print("Complaint was rated as ", scores['neu']*100, "% Neutral") 
    print("Complaint was rated as ", scores['pos']*100, "% Positive") 
    print("Complaint is overall Rated As", end = " ") 
    if scores['compound'] >= 0.05 : 
        print("POSITIVE") 
        str =  "Positive"
  
    elif scores['compound'] <= - 0.05 : 
        print("NEGATIVE") 
        str =  "Negative"
  
    else : 
        print("NEUTRAL")
        str =  "Neutral"
    return str
'''def sentiment_analyse(sentiment_text):
    score = SentimentIntensityAnalyzer().polarity_scores(sentiment_text)
    if score['neg'] > score['pos']:
        print("NEGATIVE SENTIMENT")
        return "NEGATIVE SENTIMENT"
    elif score['neg'] < score['pos']:
        print("POSITIVE SENTIMENT")
        return "POSITIVE SENTIMENT"
    else:
        print("NEUTRAL SENTIMENT")
        return "NEUTRAL SENTIMENT"'''

        
dataframe=pd.read_excel(r'C:\Users\acer\Desktop\Python\TicketSamples.xls')
x1=dataframe["CustomerReportCommunication"]
a1=x1[0:100]
stop_words = [ 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your',
              'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', 
              "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 
              'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had',
              'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 
              'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 
              'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 
              'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 
              'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 
              's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 
              'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 
              'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', 
              "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 
              'wouldn', "wouldn't", 'morning', 'good', 'greetings', 'regards', 'thanks', 'afternoon', 'thank', 'you', 'hello',
              'hi', 'support', 'hey', 'vital', 'evening', 'please' , 'today', 'see', 'default' , 'following']
loc = (r"C:\Users\acer\Desktop\Python\TicketSamples.xls") 
  
wb = xlrd.open_workbook(loc) 
sheet = wb.sheet_by_index(0) 
a=[]
for i in range(sheet.nrows-1):
      print("\n\nBEFORE PROCESSING:\n",i+1,end=".")
      print(a1[i],"\n")  
      l1=[]
      l1=sheet.cell_value(i+1,6)
      l2=l1.lower()
      tokenized_words = word_tokenize(l2, "english")
      final_words = []
      for word in tokenized_words:
         if word not in stop_words:
            final_words.append(word)
      #print(final_words)      
      a.append(str(sentiment_scores(listToString(final_words))))
      #print("\n\n\n\n")
w = Counter(list(a))
print("\n")
print(w)
# Out:
# BEFORE PROCESSING:
#  1.Good afternoon,
# We received a RPP/Covid sample from Executive Medical for XXXXXX, unfortunately there isn't an order in Vital for her. Can we get one created, please? Let me know if you have any questions.
# Thank you,
#
# POST PROCESSING:
#  , received rpp/covid sample executive medical xxxxxx , unfortunately n't order . get one created , ? let know questions . ,
#
# Overall sentiment dictionary is:  {'neg': 0.138, 'neu': 0.747, 'pos': 0.115, 'compound': -0.1027}
# Complaint was rated as  13.8 % Negative
# Complaint was rated as  74.7 % Neutral
# Complaint was rated as  11.5 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  2.Hello,
# I noticed that the Sanford guide did not attach to the 4 UTI results for today. Please make fixing this issue a top priority as our groups heavily rely on this information to help guide treatment.
# Yesterday’s UTI results upload with no issue. What caused the Sanford guide to not attach to today’s results?
# Regards,
#
# POST PROCESSING:
#  , noticed sanford guide attach 4 uti results . make fixing issue top priority groups heavily rely information help guide treatment . yesterday ’ uti results upload issue . caused sanford guide attach ’ results ? ,
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.852, 'pos': 0.148, 'compound': 0.5423}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  85.2 % Neutral
# Complaint was rated as  14.799999999999999 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  3.Hi Support.  Please see attached default test request for Connecticut Foot Care Centers, LLC.  Please advise once completed.
#
#
#
# POST PROCESSING:
#  . attached test request connecticut foot care centers , llc . advise completed .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.738, 'pos': 0.262, 'compound': 0.4939}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  73.8 % Neutral
# Complaint was rated as  26.200000000000003 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  4.Has been finalized but needs to be removed as the office said this was not the pt blood
#
# POST PROCESSING:
#  finalized needs removed office said pt blood
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  5.Hey guys,
# Would it be possible to make the drop down box at accessioning select Bill to Patient when self pa is inserted in the insurance field?
#
# POST PROCESSING:
#  guys , would possible make drop box accessioning select bill patient self pa inserted insurance field ?
#
# Overall sentiment dictionary is:  {'neg': 0.13, 'neu': 0.87, 'pos': 0.0, 'compound': -0.2732}
# Complaint was rated as  13.0 % Negative
# Complaint was rated as  87.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  6.Hey Guys,
# Is there a way we could build in a feature to stop someone from accessioning orders for the same patient on the same day that would create 2 87661 CPT codes.
# For instance I don’t want my staff to be able to order a Vaginitis panel and  a Pap + CT/NG w reflex HR HPV for Ascus + Trich on the same patient with the same date of service. Because this will generate 2 tests on the patient.
# Thanks,
#
# POST PROCESSING:
#  guys , way could build feature stop someone accessioning orders patient day would create 2 87661 cpt codes . instance ’ want staff able order vaginitis panel pap + ct/ng w reflex hr hpv ascus + trich patient date service . generate 2 tests patient . ,
#
# Overall sentiment dictionary is:  {'neg': 0.057, 'neu': 0.855, 'pos': 0.088, 'compound': 0.0516}
# Complaint was rated as  5.7 % Negative
# Complaint was rated as  85.5 % Neutral
# Complaint was rated as  8.799999999999999 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  7.On the ageing report it does not seem to list all the internal case notes on a case. Is it possible to correct this?
# Thanks,
#
# POST PROCESSING:
#  ageing report seem list internal case notes case . possible correct ? ,
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  8.We have been having system problems entering new code templates since yesterday afternoon.
# There is no answer at your phone support (866) 441-0568.
# Please contact me asap today. Please call my cell xxxxxxxxx.
#
# POST PROCESSING:
#  system problems entering new code templates since yesterday . answer phone ( 866 ) 441-0568. contact asap . call cell xxxxxxxxx .
#
# Overall sentiment dictionary is:  {'neg': 0.144, 'neu': 0.856, 'pos': 0.0, 'compound': -0.4019}
# Complaint was rated as  14.399999999999999 % Negative
# Complaint was rated as  85.6 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  9.Hi, it’s Aryeh from clover meadows AV03. Some of our usernames are still not able to see any records- they keep getting no records found. Can you please fix this issue ? Here are two that I know don’t work but please look into all usernames that you have for clover meadows
# Thank you
#
# POST PROCESSING:
#  , ’ aryeh clover meadows av03 . usernames still able records- keep getting records found . fix issue ? two know ’ work look usernames clover meadows
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  10.Hi there,
# Good morning. I tried to call 866-441-0268 but nobody answered.  Florida woman care, Molecular Department is having some issue with VitalDx sending orders to instrument, Panther. It took a long time for the instrument to get the testing orders from VitalDx, when patient samples are loaded on. Also, it can only read one rack at a time. If multiple racks are loaded, it will give error message “Error while transmitting data to LIS”.   We rebooted Vital Bridge and problem still exists. This delays our work.  Help is needed ASAP!
#
#  Thanks!!
#
# POST PROCESSING:
#  , . tried call 866-441-0268 nobody answered . florida woman care , molecular department issue vitaldx sending orders instrument , panther . took long time instrument get testing orders vitaldx , patient samples loaded . also , read one rack time . multiple racks loaded , give error message “ error transmitting data lis ” . rebooted bridge problem still exists . delays work . help needed asap ! ! !
#
# Overall sentiment dictionary is:  {'neg': 0.145, 'neu': 0.76, 'pos': 0.095, 'compound': -0.4724}
# Complaint was rated as  14.499999999999998 % Negative
# Complaint was rated as  76.0 % Neutral
# Complaint was rated as  9.5 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  11.Hi Support.  We have a client, Brandywine Podiatry, that when they try to access their reports, for some reason they can only open certain cases.  Can someone please call me so I can show you on a remote session?
# Thanks,
# Jess
#
# POST PROCESSING:
#  . client , brandywine podiatry , try access reports , reason open certain cases . someone call show remote session ? , jess
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.877, 'pos': 0.123, 'compound': 0.2732}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  87.7 % Neutral
# Complaint was rated as  12.3 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  12.Hello,
# I've sent in orders from an acct Brookdale Westampton direct to Capstone that did not cross over from VO to DX.
# I need this fixed ASAP. The samples are at the lab and need these orders in order to be run. This has to be fixed before 2:30.
# Screenshots attached below to reference for order numbers, total of 24 orders
#
# POST PROCESSING:
#  , 've sent orders acct brookdale westampton direct capstone cross vo dx . need fixed asap . samples lab need orders order run . fixed 2:30. screenshots attached reference order numbers , total 24 orders
#
# Overall sentiment dictionary is:  {'neg': 0.121, 'neu': 0.879, 'pos': 0.0, 'compound': -0.6124}
# Complaint was rated as  12.1 % Negative
# Complaint was rated as  87.9 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  13.Please contact Shantel to provide resolution on her login to P4 environment being locked out.
# Thanks,
#
#
# POST PROCESSING:
#  contact shantel provide resolution login p4 environment locked . ,
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  14.Hello Praveen,
# The username “*****” appears to be locked in Vital Orders. Are you able to unlock it?. I recently reset the password
# Thanks,
#
# POST PROCESSING:
#  praveen , username “ ***** ” appears locked orders . able unlock ? . recently reset password ,
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  15.Received a request stating that the user is unable to login to VA and is getting an error stating Invalid Password.
#
# POST PROCESSING:
#  received request stating user unable login va getting error stating invalid password .
#
# Overall sentiment dictionary is:  {'neg': 0.197, 'neu': 0.803, 'pos': 0.0, 'compound': -0.4019}
# Complaint was rated as  19.7 % Negative
# Complaint was rated as  80.30000000000001 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  16.Hey Guys,
# For histology cases with the procedure “cold knife cone”, the CPT being added is 88305. This should be updated to 88307. Can you make that change? An example is below.
#
# POST PROCESSING:
#  guys , histology cases procedure “ cold knife cone ” , cpt added 88305. updated 88307. make change ? example .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  17.Support,
# This case was sent to External System, but I’m unable to click the “N/A” hyperlink to see where the case was sent. This is happening in Google Chrome and IE. Please advise.
#
# POST PROCESSING:
#  , case sent external system , ’ unable click “ n/a ” hyperlink case sent . happening google chrome ie . advise .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  18.Good morning Vital,
# The attached case crossed as an electronic order.  When we attempt to complete the accession, there is an error message that will not allow us to proceed.  Could you please investigate this issue?
#
# POST PROCESSING:
#  , attached case crossed electronic order . attempt complete accession , error message allow us proceed . could investigate issue ?
#
# Overall sentiment dictionary is:  {'neg': 0.145, 'neu': 0.753, 'pos': 0.102, 'compound': -0.2023}
# Complaint was rated as  14.499999999999998 % Negative
# Complaint was rated as  75.3 % Neutral
# Complaint was rated as  10.2 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  19.Hi there,We had a patient report distribution failture that causing results not shown in VA.  Accession number is XXXXXX Result was finalized on auto-verification yesterday May 4th.  There was no results in report.  When you click “view report”, it will give error message as below.
#
# POST PROCESSING:
#  , patient report distribution failture causing results shown va. accession number xxxxxx result finalized auto-verification yesterday may 4th . results report . click “ view report ” , give error message .
#
# Overall sentiment dictionary is:  {'neg': 0.1, 'neu': 0.852, 'pos': 0.048, 'compound': -0.34}
# Complaint was rated as  10.0 % Negative
# Complaint was rated as  85.2 % Neutral
# Complaint was rated as  4.8 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  20.Please take these reports out of AG Rhodes ATL and delete the patient. This was the correct doctor but the wrong facility.
#
# Thanks,
#
# POST PROCESSING:
#  take reports ag rhodes atl delete patient . correct doctor wrong facility . ,
#
# Overall sentiment dictionary is:  {'neg': 0.237, 'neu': 0.763, 'pos': 0.0, 'compound': -0.4767}
# Complaint was rated as  23.7 % Negative
# Complaint was rated as  76.3 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  21.Hello,
# AN order from Court at Palm Aire failed to cross from VO to Capstones DX
# Req#;  xxxxx
# Name: Estelle Filippelli
#
# POST PROCESSING:
#  , order court palm aire failed cross vo capstones dx req # ; xxxxx name : estelle filippelli
#
# Overall sentiment dictionary is:  {'neg': 0.378, 'neu': 0.622, 'pos': 0.0, 'compound': -0.8074}
# Complaint was rated as  37.8 % Negative
# Complaint was rated as  62.2 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  22.Hi Bips,
# As we talked,  here is another case we need your help on.  Accession number xxxxx.  It was a rejected case and we made correction on it. Then it is in “Correction-pending sign-out” status as below.  Can you revert it back to rejection case, so it won’t be hanging around as an active case?  Thanks!!
#
# POST PROCESSING:
#  bips , talked , another case need help . accession number xxxxx . rejected case made correction . “ correction-pending sign-out ” status . revert back rejection case , ’ hanging around active case ? ! !
#
# Overall sentiment dictionary is:  {'neg': 0.223, 'neu': 0.574, 'pos': 0.203, 'compound': -0.3987}
# Complaint was rated as  22.3 % Negative
# Complaint was rated as  57.4 % Neutral
# Complaint was rated as  20.3 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  23.Hi,
#
# Can you please help me upload my signature correctly?
# THank you
#
# POST PROCESSING:
#  , help upload signature correctly ?
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.526, 'pos': 0.474, 'compound': 0.4019}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  52.6 % Neutral
# Complaint was rated as  47.4 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  24.Hey guys,
# Just wanted to let you know that when I am working in the addendum of the case (Addendum Notes), none of the templated comments are available for some reason:
#
# POST PROCESSING:
#  guys , wanted let know working addendum case ( addendum notes ) , none templated comments available reason :
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  25.Hello,
# I have an error message pop up when I'm trying to order for an acct Market Street Residence.
# After I hit "Respiratory - Capstone" the error message Unable to Proceed pops up.
# I've refreshed the page a few times, and the message still comes, nothing within the patient chart is open.
# I've attached a screenshot of the error message
# This needs to be solved today, I have orders to do fro tomorrow.
#
# POST PROCESSING:
#  , error message pop 'm trying order acct market street residence . hit `` respiratory - capstone '' error message unable proceed pops . 've refreshed page times , message still comes , nothing within patient chart open . 've attached screenshot error message needs solved , orders fro tomorrow .
#
# Overall sentiment dictionary is:  {'neg': 0.168, 'neu': 0.788, 'pos': 0.044, 'compound': -0.7184}
# Complaint was rated as  16.8 % Negative
# Complaint was rated as  78.8 % Neutral
# Complaint was rated as  4.3999999999999995 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  26.The reports listed below did not cross over from Vital Axis to Arizona Institute of Urology’s EMR Urochart. I had to manually upload all of these results. Can you please have someone check the interface to see if they did go out on Theranostix’s side?
#
#
# POST PROCESSING:
#  reports listed cross axis arizona institute urology ’ emr urochart . manually upload results . someone check interface go theranostix ’ side ?
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  27.Hello,
# I've input some accounts today that I want to be bridged to the other labs
# Within Sparrow to be bridged to Capstone:
# Wareham Healthcare
# Lee Healthcare
# Wichita Center
# Within Genus to be bridged to Capstone and Sparrow:
# Lcust Grove
#
# POST PROCESSING:
#  , 've input accounts want bridged labs within sparrow bridged capstone : wareham healthcare lee healthcare wichita center within genus bridged capstone sparrow : lcust grove
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.944, 'pos': 0.056, 'compound': 0.0772}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  94.39999999999999 % Neutral
# Complaint was rated as  5.6000000000000005 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  28.Good Morning,
# Please provide COVID 19 swab test results for the following patients:
#
# POST PROCESSING:
#  , provide covid 19 swab test results patients :
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  29.Hey guys,
#
# Can you please add the below to this automated report?
# XXXX
#
#
# POST PROCESSING:
#  guys , add automated report ? xxxx
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  30.My name is Holly Alderman PA-C and Total Health Systems in Clinton Township, MI.  My log in and password no longer work and I am unable to check patients UDS.  Who do I contact about getting a new log in?
#
#
# POST PROCESSING:
#  name holly alderman pa-c total health systems clinton township , mi . log password longer work unable check patients uds . contact getting new log ?
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  31.Hey guys,
# We are still having in issue with the case below. We need this resolved so the patient can get her results.
# Case XXXXXXXX.  I can print an instrument run report if you want to fax.   VA has no report.
# Thanks,
# POST PROCESSING:
#  guys , still issue case . need resolved patient get results . case xxxxxxxx . print instrument run report want fax . va report . ,
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.85, 'pos': 0.15, 'compound': 0.25}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  85.0 % Neutral
# Complaint was rated as  15.0 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  32.Hello,
# Can we please add an option called “INP” (Stands for INSURANCE NOT PROVIDED) to this field in the ACCESSIONING screen.
#
#
# POST PROCESSING:
#  , add option called “ inp ” ( stands insurance provided ) field accessioning screen .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  33.Kindly provide an update for the status of the reports requested below.
#
# Regards,
# Andrea
#
# POST PROCESSING:
#  kindly provide update status reports requested . , andrea
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.652, 'pos': 0.348, 'compound': 0.4939}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  65.2 % Neutral
# Complaint was rated as  34.8 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  34.The molecular volume report does not include indeterminate results. Could we please get this added?
#
# POST PROCESSING:
#  molecular volume report include indeterminate results . could get added ?
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  35.Hello,
# Can you please check this case out?  Please see below, Dr. Lin doesn’t have a diagnostic tab nor CPT.
# xxxxxx:: UroVysion FISH
# Thank you.
#
# POST PROCESSING:
#  , check case ? , dr. lin ’ diagnostic tab cpt . xxxxxx : : urovysion fish .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  36.Good Morning,
# It appears our spreadsheet “Cabinet 1 – Live” has been accidently deleted from the server.  We use this one daily and hope you could retrieve it for us.
# It was in SDX-Dept_Folders (U:) > I_Accessioning > Buccal & Tissue Storage > Cabinet 1 – Live
#  believe it was last opened on computer station 1 (Shirley’s computer).
#
# POST PROCESSING:
#  , appears spreadsheet “ cabinet 1 – live ” accidently deleted server . use one daily hope could retrieve us . sdx-dept_folders ( u : ) > i_accessioning > buccal & tissue storage > cabinet 1 – live believe last opened computer station 1 ( shirley ’ computer ) .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.903, 'pos': 0.097, 'compound': 0.4404}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  90.3 % Neutral
# Complaint was rated as  9.700000000000001 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  37.Good morning,
# I'm having trouble logging into a Vital orders for an account Brookdale West Orange
# ogin is: XXXXX
#
# POST PROCESSING:
#  , 'm trouble logging orders account brookdale west orange ogin : xxxxx
#
# Overall sentiment dictionary is:  {'neg': 0.231, 'neu': 0.769, 'pos': 0.0, 'compound': -0.4019}
# Complaint was rated as  23.1 % Negative
# Complaint was rated as  76.9 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  38.Hey Guys,
# I have another new feature request.
# Molecular has spent a lot of time thinking about the most efficient way for them to sign out completed test results from the panther. What they would like is below. To achieve this we would need Vital Axis to accept the worklist ID from the Panther instrument, which Hologic has confirmed can be sent through the interface message.
#
# Molecular tech logs into Vital Axis to approve and finalize molecular test results.
#
# Tech Goes to cases tab.
# Tech selects Molecular pending approval worklist – this worklist includes all cases “W or M” that have a molecular test that needs to be approved.
# Tech then groups the list by Panther Worklist ID
# All cases have a clipboard that is color coded to the result type that needs approval
# Blue= negative
# Red = Positive
# Black = Invalid
#  Wenjie, please let me know if I missed anything.
#
# POST PROCESSING:
#  guys , another new feature request . molecular spent lot time thinking efficient way sign completed test results panther . would like . achieve would need axis accept worklist id panther instrument , hologic confirmed sent interface message . molecular tech logs axis approve finalize molecular test results . tech goes cases tab . tech selects molecular pending approval worklist – worklist includes cases “ w ” molecular test needs approved . tech groups list panther worklist id cases clipboard color coded result type needs approval blue= negative red = positive black = invalid wenjie , let know missed anything .
#
# Overall sentiment dictionary is:  {'neg': 0.058, 'neu': 0.74, 'pos': 0.202, 'compound': 0.9274}
# Complaint was rated as  5.800000000000001 % Negative
# Complaint was rated as  74.0 % Neutral
# Complaint was rated as  20.200000000000003 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  39.Please create an account for Tara Dufala that mirrors my access and rights within VitalAxis.  She should have Lab Administrator and Lab Technician for NJU.
#
# POST PROCESSING:
#  create account tara dufala mirrors access rights within vitalaxis . lab administrator lab technician nju .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.861, 'pos': 0.139, 'compound': 0.2732}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  86.1 % Neutral
# Complaint was rated as  13.900000000000002 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  40.Hello,
# An order for Buckingham Houston didnt cross over from VO to Sparrow's DX
# Req attached below
#
# POST PROCESSING:
#  , order buckingham houston didnt cross vo sparrow 's dx req attached
#
# Overall sentiment dictionary is:  {'neg': 0.286, 'neu': 0.714, 'pos': 0.0, 'compound': -0.6124}
# Complaint was rated as  28.599999999999998 % Negative
# Complaint was rated as  71.39999999999999 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  41.Hello Support,
#
# Can you please active my vital collect account UN” XXXX”.
#
# POST PROCESSING:
#  , active collect account un ” xxxx ” .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.4019}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  59.699999999999996 % Neutral
# Complaint was rated as  40.300000000000004 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  42.Would you please add the following note to all the facilities in the attached Spreadsheet since they are imported facilities and we can not:
# Change send-in lab to "Genus3" Choose Header as Capstone. Bill to Please and thank you!
#
# POST PROCESSING:
#  would add note facilities attached spreadsheet since imported facilities : change send-in lab `` genus3 '' choose header capstone . bill !
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  43.Hello All,
# We would like the CPT codes for signed cases to show up for this TC/PC client’s reports on the report template similar to the CPT codes at the bottom of global Omni reports.
# Also all CPT codes signed under this facility should be professional and have the -26 modifier after every code.
# Please make this change ASAP as Dr. Kamal will be signing cases tomorrow.
# Thank you
#
# POST PROCESSING:
#  , would like cpt codes signed cases show tc/pc client ’ reports report template similar cpt codes bottom global omni reports . also cpt codes signed facility professional -26 modifier every code . make change asap dr. kamal signing cases tomorrow .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.935, 'pos': 0.065, 'compound': 0.3612}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  93.5 % Neutral
# Complaint was rated as  6.5 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  44.Good Evening,
# We received a 26 Jar Prostate from IMP and are unable select the correct amount of jars. KO prostates currently cap at 24 jars in VA.  Can we please have this corrected so we can push this case through?
# For reference: K041051
# Thank You
#
# POST PROCESSING:
#  , received 26 jar prostate imp unable select correct amount jars . ko prostates currently cap 24 jars va. corrected push case ? reference : k041051
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  45.Hello,
# I have new accounts that need bridging within VO
# In Genus DX that need briding to Sparrow and Capstone
# Watercress Newnan
# Anchor Bay East Providence
# Within Sparrow DX that need briding to Capstone and Genus
# Cadia Healthcare
# Hillcrest Nursing
# Lakeside Health and Rehab
# Mgate Health and Rehab
#
# POST PROCESSING:
#  , new accounts need bridging within vo genus dx need briding sparrow capstone watercress newnan anchor bay east providence within sparrow dx need briding capstone genus cadia healthcare hillcrest nursing lakeside health rehab mgate health rehab
#
# Overall sentiment dictionary is:  {'neg': 0.195, 'neu': 0.805, 'pos': 0.0, 'compound': -0.8402}
# Complaint was rated as  19.5 % Negative
# Complaint was rated as  80.5 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  46.My log in to this environment https://thx.vitalaxis.com/VALogin.aspx is blocked.
# Thank you
#
# POST PROCESSING:
#  log environment https : //thx.vitalaxis.com/valogin.aspx blocked .
#
# Overall sentiment dictionary is:  {'neg': 0.344, 'neu': 0.656, 'pos': 0.0, 'compound': -0.2732}
# Complaint was rated as  34.4 % Negative
# Complaint was rated as  65.60000000000001 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  47.Can you please reset my Englewood Login for Vitalaxis – I’m locked out.
#
# Also can you reset Nolvia Blanco’s Englewood login as well.  She is back at work and is also locked out.
#  Thank you
#
# POST PROCESSING:
#  reset englewood login vitalaxis – ’ locked . also reset nolvia blanco ’ englewood login well . back work also locked .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.877, 'pos': 0.123, 'compound': 0.2732}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  87.7 % Neutral
# Complaint was rated as  12.3 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  48.Hi Bips,
#
# Please investigate why the message is being re sent. Please refer to the case we were talking about this morning.
#
# Thank you
#
# POST PROCESSING:
#  bips , investigate message sent . refer case talking .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  49.Hi all,
# Can someone help me unlock Adriana’s VA portal access so she can get their needed results please and thank you
# User ID ASaucedo
# Kind Regards,
#
# POST PROCESSING:
#  , someone help unlock adriana ’ va portal access get needed results user id asaucedo kind ,
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.663, 'pos': 0.337, 'compound': 0.7269}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  66.3 % Neutral
# Complaint was rated as  33.7 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  50.Hello all,
# This result is not in vital orders. Can you please assist?
# Megan Reinhardt
#
# POST PROCESSING:
#  , result orders . assist ? megan reinhardt
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  51.   I sent an email last week asking that someone reset my password because I am locked out.
# Can someone unlock or reset me?
#
# POST PROCESSING:
#  sent email last week asking someone reset password locked . someone unlock reset ?
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  52.Hello,
# I spoke to Bips regarding not being able to view any archived reports:
# Archived cases: xx xx xx xx
#
#
# POST PROCESSING:
#  , spoke bips regarding able view archived reports : archived cases : xx xx xx xx
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  53.Please disable the remote printing for our new client Harold Mermelstein, MD – for both locations they are satisfied with only receiving their reports electronically – they do no want hard copies.
#
# POST PROCESSING:
#  disable remote printing new client harold mermelstein , md – locations satisfied receiving reports electronically – want hard copies .
#
# Overall sentiment dictionary is:  {'neg': 0.076, 'neu': 0.703, 'pos': 0.222, 'compound': 0.4019}
# Complaint was rated as  7.6 % Negative
# Complaint was rated as  70.3 % Neutral
# Complaint was rated as  22.2 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  54.Until 5 minutes ago, they were able to go back in the case print. Now, they are not able to print at all.  They are putting these cases to the side for the next 15 minutes in hopes of being able to print.
#
# POST PROCESSING:
#  5 minutes ago , able go back case print . , able print . putting cases side next 15 minutes hopes able print .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.859, 'pos': 0.141, 'compound': 0.4215}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  85.9 % Neutral
# Complaint was rated as  14.099999999999998 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  55.Vital orders appears to be down again.
#
# POST PROCESSING:
#  orders appears .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  56.Hello Team,
# Sarah Angell for FWC – Athena team has informed us that one of the PDF (Patient result) was corrupted when the results reached the chart.
# Details on the mail below.
# Please look into the issue,,
# Thank you''
#
# POST PROCESSING:
#  team , sarah angell fwc – athena team informed us one pdf ( patient result ) corrupted results reached chart . details mail . look issue , , ''
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.935, 'pos': 0.065, 'compound': 0.1027}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  93.5 % Neutral
# Complaint was rated as  6.5 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  57.Please check why she is not able to see the case in her sales login
#
# POST PROCESSING:
#  check able case sales login
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  58.Can you make VA move this case from the assignment queue? Tejas pathology set up had the “use VA to report” check box checked. It should be TC only.
#
# POST PROCESSING:
#  make va move case assignment queue ? tejas pathology set “ use va report ” check box checked . tc .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  59.Hi,
# Bucks County GI would like to change the printer where their results are printing. Currently they are printing to a printer in the office at Freedom Pathology. We would now like them to print to a printer on site at Bucks County GI. Can someone reach out to Marianne Kirk on Thursday between 9-12 to set this up?
#
#
# POST PROCESSING:
#  , bucks county gi would like change printer results printing . currently printing printer office freedom pathology . would like print printer site bucks county gi . someone reach marianne kirk thursday 9-12 set ?
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.716, 'pos': 0.284, 'compound': 0.8519}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  71.6 % Neutral
# Complaint was rated as  28.4 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  60.Hello,
# I want to set up the login below for Amarillo Multiservice Center in VitalOrders. The default password “XXXXXX” does not appear to be working for me.
#
# POST PROCESSING:
#  , want set login amarillo multiservice center vitalorders . password “ xxxxxx ” appear working .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.885, 'pos': 0.115, 'compound': 0.0772}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  88.5 % Neutral
# Complaint was rated as  11.5 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  61.Please advise. We are getting an error message of “Unable to reach host. Please contact administrator.”
#
# POST PROCESSING:
#  advise . getting error message “ unable reach host . contact administrator . ”
#
# Overall sentiment dictionary is:  {'neg': 0.25, 'neu': 0.648, 'pos': 0.102, 'compound': -0.3818}
# Complaint was rated as  25.0 % Negative
# Complaint was rated as  64.8 % Neutral
# Complaint was rated as  10.2 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  62.Vital,
# We've noticed some issues with the case detail report. The number count is off by a significant amount some days.
#
# This looks to be because it is creating the duplicate accession for EACH issue in the PIN report. Would you please consolidate that to just one accession with ALL the PIN issues in it please?
#
# We send out this report daily and the numbers are now incorrectly going out
#
# POST PROCESSING:
#  , 've noticed issues case detail report . number count significant amount days . looks creating duplicate accession issue pin report . would consolidate one accession pin issues ? send report daily numbers incorrectly going
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.836, 'pos': 0.164, 'compound': 0.5106}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  83.6 % Neutral
# Complaint was rated as  16.400000000000002 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  63.Hello Team,
# Can you provide the all the Dx templates configured for FWC split by Case type with all fields and I will edit it accordingly and send it to Brian.
# Thank you
#
# POST PROCESSING:
#  team , provide dx templates configured fwc split case type fields edit accordingly send brian .
#
# Overall sentiment dictionary is:  {'neg': 0.235, 'neu': 0.765, 'pos': 0.0, 'compound': -0.6124}
# Complaint was rated as  23.5 % Negative
# Complaint was rated as  76.5 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  64.The prefix for this case is showing as “Sagis20-“ Can you see why this is happening and can you fix this please?
#
# POST PROCESSING:
#  prefix case showing “ sagis20- “ happening fix ?
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  65.Please see the updated seed data sheet for Family First- they need the methamphetamine panel added to their profile.
#
# POST PROCESSING:
#  updated seed data sheet family first- need methamphetamine panel added profile .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  66.Hello,
# Southwest Urology, Medina location, is having issues with their dymo.  Can I schedule a call for them this coming this Friday at 2:30est?  I have let them know a log in session is necessary.   Khailiah is who you will be having the call with.  thanks
#
# POST PROCESSING:
#  , southwest urology , medina location , issues dymo . schedule call coming friday 2:30est ? let know log session necessary . khailiah call .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  67.Hey all...I was logged in and got kicked out.
# I tried closing and reloading...500-Internal server error.
# I closed & restarted my PC...500-internal server error.
# Our we down? Can you let me know when its back up?
# thanks,
#   kd
#
# POST PROCESSING:
#  ... logged got kicked . tried closing reloading ... 500-internal server error . closed & restarted pc ... 500-internal server error . ? let know back ? , kd
#
# Overall sentiment dictionary is:  {'neg': 0.224, 'neu': 0.776, 'pos': 0.0, 'compound': -0.6966}
# Complaint was rated as  22.400000000000002 % Negative
# Complaint was rated as  77.60000000000001 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  68.Hi Support.  I have a couple of casesXXXXXXX I need to make corrections to, but for some reason the option to initiate a correction doesn’t appear in the case.
# XXXXXX – Please see screenshot below.  In addition to not being able to view the PDF for the final report (the icon does not appear on the far right), the usual options that are available on the bottom right do not appear other than “View Report” and “Return.”  Please review and advise.
#
#
#
# POST PROCESSING:
#  . couple casesxxxxxxx need make corrections , reason option initiate correction ’ appear case . xxxxxx – screenshot . addition able view pdf final report ( icon appear far right ) , usual options available bottom right appear “ view report ” “ return. ” review advise .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  69.Please see below for error I keep receiving, I have tried restarting
#
# POST PROCESSING:
#  error keep receiving , tried restarting
#
# Overall sentiment dictionary is:  {'neg': 0.403, 'neu': 0.597, 'pos': 0.0, 'compound': -0.4019}
# Complaint was rated as  40.300000000000004 % Negative
# Complaint was rated as  59.699999999999996 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  70.Effective immediately, please filter Dr. Orsini’s results from going over the Greenway interface completely.
#
# POST PROCESSING:
#  effective immediately , filter dr. orsini ’ results going greenway interface completely .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.744, 'pos': 0.256, 'compound': 0.4767}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  74.4 % Neutral
# Complaint was rated as  25.6 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  71.Hello,
# There are 3 cases that were signed out earlier this afternoon and I do not see that any results have been sent through the interface yet. Can you please take a look at these cases and fix any issue there may be for this client?
#
# POST PROCESSING:
#  , 3 cases signed earlier results sent interface yet . take look cases fix issue may client ?
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  72.Vital,
#     Can we please add a new Bill to type in Vital DX?
# We would like an Uninsured option for covid patients and state billing.
# lease and thank you!
#
# POST PROCESSING:
#  , add new bill type dx ? would like uninsured option covid patients state billing . lease !
#
# Overall sentiment dictionary is:  {'neg': 0.228, 'neu': 0.639, 'pos': 0.133, 'compound': -0.4199}
# Complaint was rated as  22.8 % Negative
# Complaint was rated as  63.9 % Neutral
# Complaint was rated as  13.3 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  73.Hello,
# If the word “Medial” was remove the sites will show on the mapping.
# D-Left Medial Base
# E-Left Medial Mid
# F-Left Medial Apex
# G-Right Medial Base
# H-Right Medial Mid
# I-Right Medial Apex
# VA Support-please advise if there is any other way for these sites to map? Example: xxxxxxxx
#
# POST PROCESSING:
#  , word “ medial ” remove sites show mapping . d-left medial base e-left medial mid f-left medial apex g-right medial base h-right medial mid i-right medial apex va support-please advise way sites map ? example : xxxxxxxx
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  74.Good Morning,
# Case number xxxxxx. Block A was in Vantage.
# Blocks A2 and A3 were added in VitalAxis and did not cross over into Vantage. Ruth had to manually create the blocks.
# Thank you
#
# POST PROCESSING:
#  , case number xxxxxx . block vantage . blocks a2 a3 added vitalaxis cross vantage . ruth manually create blocks .
#
# Overall sentiment dictionary is:  {'neg': 0.318, 'neu': 0.521, 'pos': 0.161, 'compound': -0.5106}
# Complaint was rated as  31.8 % Negative
# Complaint was rated as  52.1 % Neutral
# Complaint was rated as  16.1 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  75.The ID’s are correct, not locked and active.
# Support-please advise as to why the users cannot login
#
# POST PROCESSING:
#  id ’ correct , locked active . support-please advise users login
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.722, 'pos': 0.278, 'compound': 0.4019}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  72.2 % Neutral
# Complaint was rated as  27.800000000000004 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  76.Hi All,
# See below request from Genevieve over at AUUA. Their Admin user Meg Reed has been unable to unlock Genevieve’s Portal log in. Can someone please reset her password and send to me ASAP? Thank you!
# Stay Safe and Healthy,
#
# POST PROCESSING:
#  , request genevieve auua . admin user meg reed unable unlock genevieve ’ portal log . someone reset password send asap ? ! stay safe healthy ,
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.753, 'pos': 0.247, 'compound': 0.7088}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  75.3 % Neutral
# Complaint was rated as  24.7 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  77.Vital,
#       xxxxx was finally claimed and corrected to accession xxxxx
# Wll you please delete xxxxx?
#
# POST PROCESSING:
#  , xxxxx finally claimed corrected accession xxxxx wll delete xxxxx ?
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  78.Hi Support,
# The below numbered cases signed out earlier today do not have the time stamp under the "Finalized" folder.
# S20-****
#
#
# POST PROCESSING:
#  , numbered cases signed earlier time stamp `` finalized '' folder . s20-****
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  79.Vital,
# xxx was corrected toxxxxxx Would you please xxxxxx7.... I have added the note.
#
# Trish RPP will need dropped to xxxxx
#
# POST PROCESSING:
#  , xxx corrected toxxxxxx would xxxxxx7 ... . added note . trish rpp need dropped xxxxx
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  80.Hi Support.  The auto-fax function is not working. None of our cases signed out yesterday have auto-faxed. Please investigate and remedy as soon as possible.
# Please note, I do not need the cases signed out yesterday to be auto-faxed at this point.  I have manually printed and faxed them all.  I do need you to confirm that the auto-fax feature is NOW working for cases signed out today.
#
#
#
# POST PROCESSING:
#  . auto-fax function working . none cases signed yesterday auto-faxed . investigate remedy soon possible . note , need cases signed yesterday auto-faxed point . manually printed faxed . need confirm auto-fax feature working cases signed .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  81.Good Morning,
# When I came in this morning it looks like all of Dr. ***’s reports printed at some point after I left yesterday.
# If there’s a problem again today after he signs out I will let you know.
# Thank you so much for your help.
#
# POST PROCESSING:
#  , came looks like dr. *** ’ reports printed point left yesterday . ’ problem signs let know . much help .
#
# Overall sentiment dictionary is:  {'neg': 0.129, 'neu': 0.622, 'pos': 0.249, 'compound': 0.3612}
# Complaint was rated as  12.9 % Negative
# Complaint was rated as  62.2 % Neutral
# Complaint was rated as  24.9 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  82.Good morning,
# We are experiencing marked slowness.  When you  hit save then preview report, there is nothing in the preview screen.  You have to get back to the diagnosis entry screens then the preview report area multiple times to see your report and release your case.
# hank you,
#
# POST PROCESSING:
#  , experiencing marked slowness . hit save preview report , nothing preview screen . get back diagnosis entry screens preview report area multiple times report release case . hank ,
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.878, 'pos': 0.122, 'compound': 0.4939}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  87.8 % Neutral
# Complaint was rated as  12.2 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  83.I need help for log in for Stephanie ****.
#
# POST PROCESSING:
#  need help log stephanie **** .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.597, 'pos': 0.403, 'compound': 0.4019}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  59.699999999999996 % Neutral
# Complaint was rated as  40.300000000000004 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  84.Hello,
# I spoke with Bips about the issue we are having with the faxes, just putting in this email to have a record of the ticket. Pretty much everything since yesterday morning has not faxed and will not go through even when manually distributed. Some example cases are below but its pretty much everything from yesterday onward.
#
#
# POST PROCESSING:
#  , spoke bips issue faxes , putting email record ticket . pretty much everything since yesterday faxed go even manually distributed . example cases pretty much everything yesterday onward .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.782, 'pos': 0.218, 'compound': 0.7506}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  78.2 % Neutral
# Complaint was rated as  21.8 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  85.Hello……
# The Assigned Pathologist is Out Of Office. Please select 'Yes' to re-assign the case to another available Pathologist or 'No' to continue with the same Pathologist.
# Can the above message be removed. It pops up when I click on a case number. I returned to work on Monday May 11th.
# hank u!
#
# POST PROCESSING:
#  hello…… assigned pathologist office . select 'yes ' re-assign case another available pathologist 'no ' continue pathologist . message removed . pops click case number . returned work monday may 11th . hank u !
#
# Overall sentiment dictionary is:  {'neg': 0.075, 'neu': 0.78, 'pos': 0.146, 'compound': 0.2714}
# Complaint was rated as  7.5 % Negative
# Complaint was rated as  78.0 % Neutral
# Complaint was rated as  14.6 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  86.Hello,
# Vital Orders is down.
# 5/156 @ 2:43pm
#
# POST PROCESSING:
#  , orders . 5/156 @ 2:43pm
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  87.Hello,
#
# I'm experiencing slowness while submitting orders in VO.
# Wondering if we could speed this up, please
#
# POST PROCESSING:
#  , 'm experiencing slowness submitting orders vo . wondering could speed ,
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  88.I cannot run the PAP QC Report.
# When I run it I get this pop up.  Then it doesn’t show Dr. Francus signed out any cases.
#
# POST PROCESSING:
#  run pap qc report . run get pop . ’ show dr. francus signed cases .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  89.I am requesting their results via email as I cannot get on to the login screen for the portal.
# I am one of the Nursing Supervisors from the Merkaey/A.V.S. division and need the results STAT.
#
# POST PROCESSING:
#  requesting results via email get login screen portal . one nursing supervisors merkaey/a.v.s . division need results stat .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  90.Hi, we are having an issue with the labels printing today. Robin is currently on the phone with Support, who is fixing the issue, but they said Vital Axis DX needs to be updated?
# Should all our Vital Axis' be updated? Not just the 2 being done now?
#
# POST PROCESSING:
#  , issue labels printing . robin currently phone , fixing issue , said axis dx needs updated ? axis ' updated ? 2 done ?
#
# Overall sentiment dictionary is:  {'neg': 0.232, 'neu': 0.768, 'pos': 0.0, 'compound': -0.6747}
# Complaint was rated as  23.200000000000003 % Negative
# Complaint was rated as  76.8 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  91.Hello Thejesh,
# Looks like the COVID profile is not picking the right accession sequence (SERO) for MCSO.
# Please find the accession number below to investigate.
#
# POST PROCESSING:
#  thejesh , looks like covid profile picking right accession sequence ( sero ) mcso . find accession number investigate .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.774, 'pos': 0.226, 'compound': 0.4215}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  77.4 % Neutral
# Complaint was rated as  22.6 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  92.Hello,
# We need to check the number of positives we have for BD Panel (COVID-19), we have a report that is supposed to generate data for positive cases but none of the COVID cases are showing up.
#
# POST PROCESSING:
#  , need check number positives bd panel ( covid-19 ) , report supposed generate data positive cases none covid cases showing .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.628, 'pos': 0.372, 'compound': 0.8074}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  62.8 % Neutral
# Complaint was rated as  37.2 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  93.Hello,Were noticing some random fails from VO to DX in various accounts.
# In most instances, I'm ordering multiple patients and most will cross over and one or so will fail.
# It's creating a lag in our processing because the lab has to tell me they don't see the order, I have to investigate and then send them the Req I made.
# I have 2 examples, but if we could find a solution so orders don't randomly fail (easier said than done I know) the entire team would greatly appreciate it
#
# POST PROCESSING:
#  , noticing random fails vo dx various accounts . instances , 'm ordering multiple patients cross one fail . 's creating lag processing lab tell n't order , investigate send req made . 2 examples , could find solution orders n't randomly fail ( easier said done know ) entire team would greatly appreciate
#
# Overall sentiment dictionary is:  {'neg': 0.304, 'neu': 0.574, 'pos': 0.123, 'compound': -0.9009}
# Complaint was rated as  30.4 % Negative
# Complaint was rated as  57.4 % Neutral
# Complaint was rated as  12.3 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  94.Hello,
# We get a pop-up error when trying to place an order in one of our accounts, Residence at Pearl Street.
# After we hit select the order option or any order option for that matter, we get "Unable to Proceed"
# I've attached a screenshot of that message
# This needs to be fixed as soon as possible, we have orders to do tonight
# I recall this happening once before with a new account. I think it was a configuration issue.
#
# POST PROCESSING:
#  , get pop-up error trying place order one accounts , residence pearl street . hit select order option order option matter , get `` unable proceed '' 've attached screenshot message needs fixed soon possible , orders tonight recall happening new account . think configuration issue .
#
# Overall sentiment dictionary is:  {'neg': 0.065, 'neu': 0.909, 'pos': 0.026, 'compound': -0.3818}
# Complaint was rated as  6.5 % Negative
# Complaint was rated as  90.9 % Neutral
# Complaint was rated as  2.6 % Positive
# Complaint is overall Rated As NEGATIVE
#
#
# BEFORE PROCESSING:
#  95.Hello,
# Vital Orders is down.
# We are not able to log in
# Please resolve as soon as possible
#
# POST PROCESSING:
#  , orders . able log resolve soon possible
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 0.658, 'pos': 0.342, 'compound': 0.3818}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  65.8 % Neutral
# Complaint was rated as  34.2 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  96.Good morning,
# VO is being slow today. I'm experiencing it while logging in and submitting orders
#
# POST PROCESSING:
#  , vo slow . 'm experiencing logging submitting orders
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  97.I am having a hard time entering all these residents. The site is moving super slow. I have tried several different browsers. Also, somehow a patient is locked and I can’t seem to find how to unlock it. Please call me ASAP! We have tests on the way to you.
#
# POST PROCESSING:
#  hard time entering residents . site moving super slow . tried several different browsers . also , somehow patient locked ’ seem find unlock . call asap ! tests way .
#
# Overall sentiment dictionary is:  {'neg': 0.053, 'neu': 0.79, 'pos': 0.158, 'compound': 0.5848}
# Complaint was rated as  5.3 % Negative
# Complaint was rated as  79.0 % Neutral
# Complaint was rated as  15.8 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# BEFORE PROCESSING:
#  98.Hello,
# After 33 seconds of waiting for a send out req to appear on the screen, the following message appears. It is happening on all workstations.
#
# POST PROCESSING:
#  , 33 seconds waiting send req appear screen , message appears . happening workstations .
#
# Overall sentiment dictionary is:  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# Complaint was rated as  0.0 % Negative
# Complaint was rated as  100.0 % Neutral
# Complaint was rated as  0.0 % Positive
# Complaint is overall Rated As NEUTRAL
#
#
# BEFORE PROCESSING:
#  99.Hello-
# For xxxxx, the report came through without test results, which usually happens if a report type is dropped, but the corresponding order is not there (ex: COVID data dropped, but no order for COVID). This case did have the COVID order, but the report does not have results (below). I redropped the data and the report was successfully produced with results.
# There are other reports like this from Atrium Matawan facility. Here is another one for reference. xxxxxx
#
# 1) What is causing this error?
# 2) How do we identify what reports are incorrect?
# 3) How do we fix it?
#
# POST PROCESSING:
#  hello- xxxxx , report came without test results , usually happens report type dropped , corresponding order ( ex : covid data dropped , order covid ) . case covid order , report results ( ) . redropped data report successfully produced results . reports like atrium matawan facility . another one reference . xxxxxx 1 ) causing error ? 2 ) identify reports incorrect ? 3 ) fix ?
#
# Overall sentiment dictionary is:  {'neg': 0.052, 'neu': 0.828, 'pos': 0.12, 'compound': 0.5484}
# Complaint was rated as  5.2 % Negative
# Complaint was rated as  82.8 % Neutral
# Complaint was rated as  12.0 % Positive
# Complaint is overall Rated As POSITIVE
#
#
# Counter({'Neutral': 40, 'Positive': 34, 'Negative': 25})
