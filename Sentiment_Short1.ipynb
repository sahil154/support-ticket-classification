# %%
# Sentiment Analysis With FEW STOPWORDS
import string
import pandas as pd

from collections import Counter

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer

from nltk.tokenize import word_tokenize
import xlrd 
def listToString(s):   
    str1 = ""  
    for ele in s:  
        str1 += ele 
        str1+=" "
    return str1

def sentiment_analyse(sentiment_text):
    score = SentimentIntensityAnalyzer().polarity_scores(sentiment_text)
    if score['neg'] > score['pos']:
        print("NEGATIVE SENTIMENT")
        return "NEGATIVE SENTIMENT"
    elif score['neg'] < score['pos']:
        print("POSITIVE SENTIMENT")
        return "POSITIVE SENTIMENT"
    else:
        print("NEUTRAL SENTIMENT")
        return "NEUTRAL SENTIMENT"

        
dataframe=pd.read_excel(r'C:\Users\acer\Desktop\Python\TicketSamples.xls')
x1=dataframe["CustomerReportCommunication"]
a1=x1[0:100]
stopwords1=['good', 'morning','afternoon','evening','thanks','hello','regards','thank','kind regards',',']  
loc = (r"C:\Users\acer\Desktop\Python\TicketSamples.xls") 
  
wb = xlrd.open_workbook(loc) 
sheet = wb.sheet_by_index(0) 
a=[]
for i in range(sheet.nrows-1):
      print(i+1,end=".")
      #print(a1[i],"  - ",end=" ")  
      l1=[]
      l1=sheet.cell_value(i+1,6)
      l2=l1.lower()
      tokenized_words = word_tokenize(l2, "english")
      final_words = []
      for word in tokenized_words:
         if word not in stopwords1:
            final_words.append(word)
      a.append(str(sentiment_analyse(listToString(final_words))))
      #print("\n\n\n\n")
w = Counter(list(a))
print("\n")
print(w)
# Out:
# 1.POSITIVE SENTIMENT
# 2.POSITIVE SENTIMENT
# 3.POSITIVE SENTIMENT
# 4.NEUTRAL SENTIMENT
# 5.NEGATIVE SENTIMENT
# 6.POSITIVE SENTIMENT
# 7.NEUTRAL SENTIMENT
# 8.POSITIVE SENTIMENT
# 9.POSITIVE SENTIMENT
# 10.POSITIVE SENTIMENT
# 11.POSITIVE SENTIMENT
# 12.NEGATIVE SENTIMENT
# 13.POSITIVE SENTIMENT
# 14.POSITIVE SENTIMENT
# 15.NEGATIVE SENTIMENT
# 16.NEUTRAL SENTIMENT
# 17.POSITIVE SENTIMENT
# 18.POSITIVE SENTIMENT
# 19.NEGATIVE SENTIMENT
# 20.NEGATIVE SENTIMENT
# 21.NEGATIVE SENTIMENT
# 22.POSITIVE SENTIMENT
# 23.POSITIVE SENTIMENT
# 24.NEUTRAL SENTIMENT
# 25.NEGATIVE SENTIMENT
# 26.POSITIVE SENTIMENT
# 27.POSITIVE SENTIMENT
# 28.POSITIVE SENTIMENT
# 29.POSITIVE SENTIMENT
# 30.NEGATIVE SENTIMENT
# 31.POSITIVE SENTIMENT
# 32.POSITIVE SENTIMENT
# 33.POSITIVE SENTIMENT
# 34.POSITIVE SENTIMENT
# 35.POSITIVE SENTIMENT
# 36.POSITIVE SENTIMENT
# 37.NEGATIVE SENTIMENT
# 38.POSITIVE SENTIMENT
# 39.POSITIVE SENTIMENT
# 40.NEGATIVE SENTIMENT
# 41.POSITIVE SENTIMENT
# 42.POSITIVE SENTIMENT
# 43.POSITIVE SENTIMENT
# 44.POSITIVE SENTIMENT
# 45.NEGATIVE SENTIMENT
# 46.NEGATIVE SENTIMENT
# 47.POSITIVE SENTIMENT
# 48.POSITIVE SENTIMENT
# 49.POSITIVE SENTIMENT
# 50.POSITIVE SENTIMENT
# 51.NEUTRAL SENTIMENT
# 52.NEUTRAL SENTIMENT
# 53.POSITIVE SENTIMENT
# 54.POSITIVE SENTIMENT
# 55.POSITIVE SENTIMENT
# 56.POSITIVE SENTIMENT
# 57.POSITIVE SENTIMENT
# 58.NEUTRAL SENTIMENT
# 59.POSITIVE SENTIMENT
# 60.POSITIVE SENTIMENT
# 61.POSITIVE SENTIMENT
# 62.POSITIVE SENTIMENT
# 63.NEGATIVE SENTIMENT
# 64.POSITIVE SENTIMENT
# 65.POSITIVE SENTIMENT
# 66.NEUTRAL SENTIMENT
# 67.NEGATIVE SENTIMENT
# 68.POSITIVE SENTIMENT
# 69.NEGATIVE SENTIMENT
# 70.POSITIVE SENTIMENT
# 71.POSITIVE SENTIMENT
# 72.POSITIVE SENTIMENT
# 73.NEUTRAL SENTIMENT
# 74.NEGATIVE SENTIMENT
# 75.NEGATIVE SENTIMENT
# 76.POSITIVE SENTIMENT
# 77.POSITIVE SENTIMENT
# 78.POSITIVE SENTIMENT
# 79.POSITIVE SENTIMENT
# 80.POSITIVE SENTIMENT
# 81.POSITIVE SENTIMENT
# 82.POSITIVE SENTIMENT
# 83.POSITIVE SENTIMENT
# 84.POSITIVE SENTIMENT
# 85.POSITIVE SENTIMENT
# 86.POSITIVE SENTIMENT
# 87.POSITIVE SENTIMENT
# 88.NEUTRAL SENTIMENT
# 89.NEUTRAL SENTIMENT
# 90.POSITIVE SENTIMENT
# 91.POSITIVE SENTIMENT
# 92.POSITIVE SENTIMENT
# 93.NEGATIVE SENTIMENT
# 94.NEGATIVE SENTIMENT
# 95.POSITIVE SENTIMENT
# 96.NEUTRAL SENTIMENT
# 97.POSITIVE SENTIMENT
# 98.NEUTRAL SENTIMENT
# 99.POSITIVE SENTIMENT
#
#
# Counter({'POSITIVE SENTIMENT': 67, 'NEGATIVE SENTIMENT': 19, 'NEUTRAL SENTIMENT': 13})

# %%
#Sentiment Analysis With ALL STOPWORDS
import string
import nltk
import pandas as pd

from collections import Counter

from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize
import xlrd 
def listToString(s):   
    str1 = ""  
    for ele in s:  
        str1 += ele 
        str1+=" "
    return str1

def sentiment_analyse(sentiment_text):
    score = SentimentIntensityAnalyzer().polarity_scores(sentiment_text)
    if score['neg'] > score['pos']:
        print("NEGATIVE SENTIMENT")
        return "NEGATIVE SENTIMENT"
    elif score['neg'] < score['pos']:
        print("POSITIVE SENTIMENT")
        return "POSITIVE SENTIMENT"
    else:
        print("NEUTRAL SENTIMENT")
        return "NEUTRAL SENTIMENT"

        
dataframe=pd.read_excel(r'C:\Users\acer\Desktop\Python\TicketSamples.xls')
x1=dataframe["CustomerReportCommunication"]
a1=x1[0:100]
stopwords1=['good', 'morning','afternoon','evening','thanks','hello','regards','thank','kind regards',','] 
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(stopwords1)
loc = (r"C:\Users\acer\Desktop\Python\TicketSamples.xls") 
  
wb = xlrd.open_workbook(loc) 
sheet = wb.sheet_by_index(0) 
a=[]
for i in range(sheet.nrows-1):
      print(i+1,end=".")
      #print(a1[i],"  - ",end=" ")  
      l1=[]
      l1=sheet.cell_value(i+1,6)
      l2=l1.lower()
      tokenized_words = word_tokenize(l2, "english")
      final_words = []
      for word in tokenized_words:
         if word not in stopwords:
            final_words.append(word)
      #print(final_words)      
      a.append(str(sentiment_analyse(listToString(final_words))))
      #print("\n\n\n\n")
w = Counter(list(a))
print("\n")
print(w)
# Out:
# 1.NEUTRAL SENTIMENT
# 2.POSITIVE SENTIMENT
# 3.POSITIVE SENTIMENT
# 4.NEUTRAL SENTIMENT
# 5.NEGATIVE SENTIMENT
# 6.POSITIVE SENTIMENT
# 7.NEUTRAL SENTIMENT
# 8.POSITIVE SENTIMENT
# 9.POSITIVE SENTIMENT
# 10.NEUTRAL SENTIMENT
# 11.POSITIVE SENTIMENT
# 12.NEGATIVE SENTIMENT
# 13.POSITIVE SENTIMENT
# 14.POSITIVE SENTIMENT
# 15.NEGATIVE SENTIMENT
# 16.NEUTRAL SENTIMENT
# 17.POSITIVE SENTIMENT
# 18.POSITIVE SENTIMENT
# 19.NEGATIVE SENTIMENT
# 20.NEGATIVE SENTIMENT
# 21.NEGATIVE SENTIMENT
# 22.NEGATIVE SENTIMENT
# 23.POSITIVE SENTIMENT
# 24.NEUTRAL SENTIMENT
# 25.NEGATIVE SENTIMENT
# 26.POSITIVE SENTIMENT
# 27.POSITIVE SENTIMENT
# 28.POSITIVE SENTIMENT
# 29.POSITIVE SENTIMENT
# 30.NEUTRAL SENTIMENT
# 31.POSITIVE SENTIMENT
# 32.POSITIVE SENTIMENT
# 33.POSITIVE SENTIMENT
# 34.POSITIVE SENTIMENT
# 35.POSITIVE SENTIMENT
# 36.POSITIVE SENTIMENT
# 37.NEGATIVE SENTIMENT
# 38.POSITIVE SENTIMENT
# 39.POSITIVE SENTIMENT
# 40.NEGATIVE SENTIMENT
# 41.POSITIVE SENTIMENT
# 42.POSITIVE SENTIMENT
# 43.POSITIVE SENTIMENT
# 44.POSITIVE SENTIMENT
# 45.NEGATIVE SENTIMENT
# 46.NEGATIVE SENTIMENT
# 47.POSITIVE SENTIMENT
# 48.POSITIVE SENTIMENT
# 49.POSITIVE SENTIMENT
# 50.POSITIVE SENTIMENT
# 51.NEUTRAL SENTIMENT
# 52.NEUTRAL SENTIMENT
# 53.POSITIVE SENTIMENT
# 54.POSITIVE SENTIMENT
# 55.POSITIVE SENTIMENT
# 56.POSITIVE SENTIMENT
# 57.POSITIVE SENTIMENT
# 58.NEUTRAL SENTIMENT
# 59.POSITIVE SENTIMENT
# 60.POSITIVE SENTIMENT
# 61.POSITIVE SENTIMENT
# 62.POSITIVE SENTIMENT
# 63.NEGATIVE SENTIMENT
# 64.POSITIVE SENTIMENT
# 65.POSITIVE SENTIMENT
# 66.NEUTRAL SENTIMENT
# 67.NEGATIVE SENTIMENT
# 68.POSITIVE SENTIMENT
# 69.NEGATIVE SENTIMENT
# 70.POSITIVE SENTIMENT
# 71.POSITIVE SENTIMENT
# 72.POSITIVE SENTIMENT
# 73.NEUTRAL SENTIMENT
# 74.NEGATIVE SENTIMENT
# 75.POSITIVE SENTIMENT
# 76.POSITIVE SENTIMENT
# 77.POSITIVE SENTIMENT
# 78.POSITIVE SENTIMENT
# 79.POSITIVE SENTIMENT
# 80.POSITIVE SENTIMENT
# 81.POSITIVE SENTIMENT
# 82.POSITIVE SENTIMENT
# 83.POSITIVE SENTIMENT
# 84.POSITIVE SENTIMENT
# 85.POSITIVE SENTIMENT
# 86.POSITIVE SENTIMENT
# 87.POSITIVE SENTIMENT
# 88.NEUTRAL SENTIMENT
# 89.NEUTRAL SENTIMENT
# 90.POSITIVE SENTIMENT
# 91.POSITIVE SENTIMENT
# 92.POSITIVE SENTIMENT
# 93.NEGATIVE SENTIMENT
# 94.NEGATIVE SENTIMENT
# 95.POSITIVE SENTIMENT
# 96.NEUTRAL SENTIMENT
# 97.POSITIVE SENTIMENT
# 98.NEUTRAL SENTIMENT
# 99.POSITIVE SENTIMENT
#
#
# Counter({'POSITIVE SENTIMENT': 65, 'NEGATIVE SENTIMENT': 18, 'NEUTRAL SENTIMENT': 16})

# %%
#Sentiment Analysis with NO STOPWORDS AT ALL
import string
import pandas as pd
from collections import Counter
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

import xlrd 
def listToString(s):   
    str1 = ""  
    for ele in s:  
        str1 += ele 
        str1+=" "
    return str1
def sentiment_analyse(sentiment_text):
    score = SentimentIntensityAnalyzer().polarity_scores(sentiment_text)
    if score['neg'] > score['pos']:
        print("NEGATIVE SENTIMENT")
        return "NEGATIVE SENTIMENT"
    elif score['neg'] < score['pos']:
        print("POSITIVE SENTIMENT")
        return "POSITIVE SENTIMENT"
    else:
        print("NEUTRAL SENTIMENT")
        return "NEUTRAL SENTIMENT"
        
dataframe=pd.read_excel(r'C:\Users\acer\Desktop\Python\TicketSamples.xls')
x1=dataframe["CustomerReportCommunication"]
a1=x1[0:100]
  
loc = (r"C:\Users\acer\Desktop\Python\TicketSamples.xls") 
  
wb = xlrd.open_workbook(loc) 
sheet = wb.sheet_by_index(0) 
a=[]
for i in range(sheet.nrows-1):
      print(i+1,end=".")
      l1=[]
      l1=sheet.cell_value(i+1,6)
      l2=l1.lower()
      tokenized_words=[]
      tokenized_words=word_tokenize(l2, "english")
      a.append(str(sentiment_analyse(listToString(tokenized_words))))
      #print("\n\n\n\n")
w = Counter(list(a))
print("\n")
print(w)
# Out:
# 1.POSITIVE SENTIMENT
# 2.POSITIVE SENTIMENT
# 3.POSITIVE SENTIMENT
# 4.NEUTRAL SENTIMENT
# 5.NEGATIVE SENTIMENT
# 6.POSITIVE SENTIMENT
# 7.POSITIVE SENTIMENT
# 8.POSITIVE SENTIMENT
# 9.POSITIVE SENTIMENT
# 10.POSITIVE SENTIMENT
# 11.POSITIVE SENTIMENT
# 12.NEGATIVE SENTIMENT
# 13.POSITIVE SENTIMENT
# 14.POSITIVE SENTIMENT
# 15.NEGATIVE SENTIMENT
# 16.NEUTRAL SENTIMENT
# 17.POSITIVE SENTIMENT
# 18.POSITIVE SENTIMENT
# 19.NEGATIVE SENTIMENT
# 20.POSITIVE SENTIMENT
# 21.NEGATIVE SENTIMENT
# 22.POSITIVE SENTIMENT
# 23.POSITIVE SENTIMENT
# 24.NEUTRAL SENTIMENT
# 25.NEGATIVE SENTIMENT
# 26.POSITIVE SENTIMENT
# 27.POSITIVE SENTIMENT
# 28.POSITIVE SENTIMENT
# 29.POSITIVE SENTIMENT
# 30.NEGATIVE SENTIMENT
# 31.POSITIVE SENTIMENT
# 32.POSITIVE SENTIMENT
# 33.POSITIVE SENTIMENT
# 34.POSITIVE SENTIMENT
# 35.POSITIVE SENTIMENT
# 36.POSITIVE SENTIMENT
# 37.POSITIVE SENTIMENT
# 38.POSITIVE SENTIMENT
# 39.POSITIVE SENTIMENT
# 40.NEGATIVE SENTIMENT
# 41.POSITIVE SENTIMENT
# 42.POSITIVE SENTIMENT
# 43.POSITIVE SENTIMENT
# 44.POSITIVE SENTIMENT
# 45.NEGATIVE SENTIMENT
# 46.POSITIVE SENTIMENT
# 47.POSITIVE SENTIMENT
# 48.POSITIVE SENTIMENT
# 49.POSITIVE SENTIMENT
# 50.POSITIVE SENTIMENT
# 51.NEUTRAL SENTIMENT
# 52.NEUTRAL SENTIMENT
# 53.POSITIVE SENTIMENT
# 54.POSITIVE SENTIMENT
# 55.POSITIVE SENTIMENT
# 56.POSITIVE SENTIMENT
# 57.POSITIVE SENTIMENT
# 58.NEUTRAL SENTIMENT
# 59.POSITIVE SENTIMENT
# 60.POSITIVE SENTIMENT
# 61.POSITIVE SENTIMENT
# 62.POSITIVE SENTIMENT
# 63.NEGATIVE SENTIMENT
# 64.POSITIVE SENTIMENT
# 65.POSITIVE SENTIMENT
# 66.POSITIVE SENTIMENT
# 67.NEGATIVE SENTIMENT
# 68.POSITIVE SENTIMENT
# 69.NEGATIVE SENTIMENT
# 70.POSITIVE SENTIMENT
# 71.POSITIVE SENTIMENT
# 72.POSITIVE SENTIMENT
# 73.NEUTRAL SENTIMENT
# 74.POSITIVE SENTIMENT
# 75.NEGATIVE SENTIMENT
# 76.POSITIVE SENTIMENT
# 77.POSITIVE SENTIMENT
# 78.POSITIVE SENTIMENT
# 79.POSITIVE SENTIMENT
# 80.POSITIVE SENTIMENT
# 81.POSITIVE SENTIMENT
# 82.POSITIVE SENTIMENT
# 83.POSITIVE SENTIMENT
# 84.POSITIVE SENTIMENT
# 85.POSITIVE SENTIMENT
# 86.POSITIVE SENTIMENT
# 87.POSITIVE SENTIMENT
# 88.NEUTRAL SENTIMENT
# 89.NEUTRAL SENTIMENT
# 90.POSITIVE SENTIMENT
# 91.POSITIVE SENTIMENT
# 92.POSITIVE SENTIMENT
# 93.NEGATIVE SENTIMENT
# 94.NEGATIVE SENTIMENT
# 95.POSITIVE SENTIMENT
# 96.POSITIVE SENTIMENT
# 97.POSITIVE SENTIMENT
# 98.NEUTRAL SENTIMENT
# 99.POSITIVE SENTIMENT
#
#
# Counter({'POSITIVE SENTIMENT': 74, 'NEGATIVE SENTIMENT': 15, 'NEUTRAL SENTIMENT': 10})
